# %% [markdown]
# <a href="https://colab.research.google.com/github/lcnature/PSY292_2024Fall/blob/main/HW_CH14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Screenshot 2024-11-14 at 12.48.59 AM.png](data:image/png;base64,...)

# %%
import numpy as np
Y1 = np.asarray([4, 3, 6, 3, 4, 7])
Y2 = np.asarray([0, 1, 3, 1, 0])

# %% [markdown]
# ![Screenshot 2024-11-14 at 1.12.18 AM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-11-14 at 1.18.15 AM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-11-14 at 1.18.22 AM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-11-14 at 1.18.28 AM.png](data:image/png;base64,...)
