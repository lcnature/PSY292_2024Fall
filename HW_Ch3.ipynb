# %% [markdown]
# <a href="https://colab.research.google.com/github/lcnature/PSY292_2024Fall/blob/main/HW_Ch3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Tip
#
# Going through the [notebook](https://colab.research.google.com/github/lcnature/PSY292_2024Fall/blob/main/notebooks/02-SummarizingData.ipynb) for **summarizing data** covered in class and the [notebook](https://colab.research.google.com/github/lcnature/PSY292_2024Fall/blob/main/notebooks/03-DataVisualization.ipynb) on **data visualization** will help you solve the problems here.
#
# You should be able to find examples of doing the same analysis for other variables in the notebooks above.

# %%
! pip install nhanes
# This installs the package for the dataset. You can ignore the output

# %%
from nhanes.load import load_NHANES_data
nhanes_data = load_NHANES_data()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# In the cells above, I imported all the packages necessary to complete the task. Please run them first. In the future, such preparation will be gradually reduced. So please try to remember the names of the package that we often use.

# %% [markdown]
# ![Screenshot 2024-08-29 at 12.46.03 AM.png](data:image/png;base64,...)
