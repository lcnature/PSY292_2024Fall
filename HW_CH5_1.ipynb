# %% [markdown]
# <a href="https://colab.research.google.com/github/lcnature/PSY292_2024Fall/blob/main/HW_CH5_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Tip:
# You should be able to find codes that are similar to the tasks here in the notebook on [summarizing data](https://colab.research.google.com/github/lcnature/PSY292_2024Fall/blob/main/notebooks/02-SummarizingData.ipynb) and [model fitting](https://colab.research.google.com/github/lcnature/statsthinking21-python/blob/master/notebooks/04-FittingSimpleModels.ipynb)

# %%
! pip install nhanes
from nhanes.load import load_NHANES_data
nhanes_data = load_NHANES_data()

# %% [markdown]
# # Importing libraries
# Please properly import the libraries `numpy` and `pandas` in the cell below

# %%
# write your code to import libraries here (your code should NOT start with "#")

# %% [markdown]
# Assuming you have imported packages properly, you should be able to run the codes below to extract the weights of adults in the data (in Kg). Please run it.

# %%
weight_adult = nhanes_data.query('AgeInYearsAtScreening > 17')[['WeightKg']]
weight_adult.head()

# %% [markdown]
# ![Screenshot 2024-09-01 at 6.34.11 PM.png](data:image/png;base64,...)

# %%
# write your code in this cell to complete the task above

# %% [markdown]
# ![Screenshot 2024-09-01 at 6.34.54 PM.png](data:image/png;base64,...)

# %%
# write your code in this cell to complete the task above

# %% [markdown]
# ![Screenshot 2024-09-01 at 6.35.36 PM.png](data:image/png;base64,...)

# %%
# write your code in this cell to complete the task above

# %% [markdown]
# - Take screenshot(s) of the last three blocks of codes and submit on Blackboard.
