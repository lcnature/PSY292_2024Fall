# %% [markdown]
# <a href="https://colab.research.google.com/github/lcnature/PSY292_2024Fall/blob/main/Ch2_HM2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Hint: if you somehow messed up with this notebook such that you cannot see the instruction, you can simply refresh the browser, or re-click the link to this notebook. Unless you save a copy of the notebook to your google drive, the change you make will be lost when you close the browser.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
