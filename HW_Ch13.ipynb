# %% [markdown]
# <a href="https://colab.research.google.com/github/lcnature/PSY292_2024Fall/blob/main/HW_Ch13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Screenshot 2024-10-30 at 3.22.36 PM.png](data:image/png;base64,...)

# %%
import numpy as np

X = [3, 8, 10, 8, 4, 7, 4, 5, 14]
Y = [11, 19, 22, 20, 14, 13, 9, 20, 25]

# %% [markdown]
# ![Screenshot 2024-10-30 at 4.11.00 PM.png](data:image/png;base64,...)
