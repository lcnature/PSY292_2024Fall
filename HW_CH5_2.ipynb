# %% [markdown]
# <a href="https://colab.research.google.com/github/lcnature/PSY292_2024Fall/blob/main/HW_CH5_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Tip:
# You may find example codes that achieve similar tasks in the notebook on [fitting models to data](https://colab.research.google.com/github/lcnature/statsthinking21-python/blob/master/notebooks/04-FittingSimpleModels.ipynb). But I encourage you to first try to do it without looking up that notebook

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# The codes below first generates a sample of 1000 numbers from a standard normal distribution, and then plot its histogram.

# %%
sample = np.random.randn(1000)
plt.hist(sample)
plt.show()
# Just run this cell, you don't need to edit it.

# %% [markdown]
# ![Screenshot 2024-09-05 at 12.43.38 AM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-09-05 at 12.44.54 AM.png](data:image/png;base64,...)

# %% [markdown]
# I am sure you have found that this sample's standard deviation is not exactly 1.0 (if you have done everything correctly), which is the standard deviation of a standard normal distribution. This is an illustration that statistics calculated from a sample will almost always deviate somewhat from the parameter of the underlying population or distribution.
